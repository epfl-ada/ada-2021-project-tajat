# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Additional datasets/adults-news-consumption-survey-combined-cati-and-online-respondent-level.csv', header=[1], low_memory=False)

# %%
df
# Out:
#      <A1> Gender <A2> What is your age? Refused exact age  \
# 0           Male                     61
# 1           Male                     39
# 2         Female                     55
# 3         Female                     54
# 4           Male                     67
# ...          ...                    ...               ...
# 4600        Male                     55
# 4601        Male                     57
# 4602        Male                     53
# 4603      Female                     75
# 4604        Male                     68
#
#      Which of the following age bands are you in? <A4> Social grade  \
# 0                                                                 B
# 1                                                                 A
# 2                                                                C1
# 3                                                                 D
# 4                                                                 A
# ...
